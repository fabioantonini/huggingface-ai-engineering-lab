# %% [markdown]
# # Course Index

# %% [markdown]
# This lab introduces practical AI engineering using Hugging Face models. Students will explore NLP, embeddings, RAG, and multimodal AI.

# %% [markdown]
# ## Setup

# %%
# !pip install transformers datasets sentence-transformers pillow -q

# %% [markdown]
# ## Imports

# %%
from transformers import pipeline
import torch
print('Torch version:', torch.__version__)

# %% [markdown]
# ## Test environment

# %%
from transformers import pipeline
classifier=pipeline('sentiment-analysis')
classifier('AI engineering is fun!')
